# %% [markdown]
# # Movement around Corners
#
# This notebook can be directly downloaded {download}`here <./corner.ipynb>` to run it locally.
#
# In the following we'll investigate the movement of pedestrians around corners. When pedestrians walk around corners they are expected to slow down and take a path that is close to the corner. According to RiMEA Test 6 [1] a scenario is configured where **20 agents** move towards a **corner** at which they should turn to the left.
#
# Let's begin by importing the required packages for our simulation:

# %%
import pathlib

import jupedsim as jps
import pedpy
from numpy.random import normal  # normal distribution of free movement speed
from shapely import Polygon

# %% [markdown]
# ## Setting up the Geometry
#
# According to the RiMEA Test we define a corridor with a width of 2 meters and a corner on halfway:

# %%
area = Polygon([(0, 0), (12, 0), (12, 12), (10, 12), (10, 2), (0, 2)])
walkable_area = pedpy.WalkableArea(area)
pedpy.plot_walkable_area(walkable_area=walkable_area).set_aspect("equal")

# %% [markdown]
# ## Definition of Start Positions and Exit
#
# Now we'll calculate the position of 20 agents in the lower left part of the geometry within an rectangle of 6 x 2 meters. For this purpose, we use a library function from JuPedSim that calclulates positions in a given polygon. We assume an agent size of 0.4 m (diameter) and set the distance parameters accordingly. The exit is defined in the upper right of the geometry.

# %%
spawning_area = Polygon([(0, 0), (6, 0), (6, 2), (0, 2)])
num_agents = 6
pos_in_spawning_area = jps.distributions.distribute_by_number(
    polygon=spawning_area,
    number_of_agents=num_agents,
    distance_to_agents=0.4,
    distance_to_polygon=0.2,
    seed=42,
)
exit_area = Polygon([(10, 11), (12, 11), (12, 12), (10, 12)])

# %% [markdown]
# Let's have a look at the basic simulation setup. The spawning area is shown in grey, the agents in blue and the exit area in red:

# %%
def plot_simulation_configuration(
    walkable_area, spawning_area, starting_positions, exit_area
):
    axes = pedpy.plot_walkable_area(walkable_area=walkable_area)
    axes.fill(*spawning_area.exterior.xy, color="lightgrey")
    axes.fill(*exit_area.exterior.xy, color="indianred")
    axes.scatter(*zip(*starting_positions))
    axes.set_xlabel("x/m")
    axes.set_ylabel("y/m")
    axes.set_aspect("equal")

# %%
plot_simulation_configuration(
    walkable_area, spawning_area, pos_in_spawning_area, exit_area
)

# %% [markdown]
# ## Setting up the Simulation and Routing Details
#
# As a next step we create a simulation object, set the configuration for the operational model (collision-free speed model) and define the routes for the agents. Default values for the model parameters are set implicitly. For this scenario, only one journey is created as all agents should follow the same route.

# %%
from jupedsim_examples.models.multi_model import MultiModel

trajectory_file = "corner.sqlite"  # output file

simulation = jps.Simulation(
    model=MultiModel(),
    geometry=area,
    trajectory_writer=jps.SqliteTrajectoryWriter(
        output_file=pathlib.Path(trajectory_file),
    ),
)

# %%
exit_id = simulation.add_exit_stage(exit_area.exterior.coords[:-1])
journey = jps.JourneyDescription([exit_id])
journey_id = simulation.add_journey(journey)

# %% [markdown]
# ## Agent Parameters and Executing the Simulation
#
# As a next step we define the agent parameters and add them to the simulation. They share the same journey and model parameters except for the starting position and free movement speed which is normally distributed. After adding the agents, the simulation is started and iterates until all agents have reached the exit.

# %%
from jupedsim_examples.models.multi_model import MultiModelAgentState
from jupedsim_examples.models.pysocial_force import PythonSocialForceModelState
from jupedsim.models.collision_free_speed_v3 import CollisionFreeSpeedModelV3State
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1623
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1624
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1625
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1626
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1627
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1628
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1629
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1630
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1631
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1632
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1633
# Model:  CFSM Before Repack, sum of agents  1
# Model:  SFM Before Repack, sum of agents  1
# iteration:  1634
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1635
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1636
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1637
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1638
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1639
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1640
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1641
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1642
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1643
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1644
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1645
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1646
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1647
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1648
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1649
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1650
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1651
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1652
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1653
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1654
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1655
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1656
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1657
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1658
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1659
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1660
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1661
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1662
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1663
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1664
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1665
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1666
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1667
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1668
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1669
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1670
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1671
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1672
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1673
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1674
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1675
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1676
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1677
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1678
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1679
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1680
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1681
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1682
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1683
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1684
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1685
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1686
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1687
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1688
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1689
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1690
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1691
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1692
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1693
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1694
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1695
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1696
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1697
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1698
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1699
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1700
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1701
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1702
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1703
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1704
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1705
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1706
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1707
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1708
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1709
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1710
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1711
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1712
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1713
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1714
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1715
# Model:  CFSM Before Repack, sum of agents  0
# iteration:  1716

# %% [markdown]
# ## Visualizing the Trajectories

# %%
from jupedsim.internal.notebook_utils import animate, read_sqlite_file
from plotly_gif import GIF, capture
gif = GIF()

trajectory_data, walkable_area = read_sqlite_file(trajectory_file)
animate(trajectory_data, walkable_area, every_nth_frame=5)
#save_gif(fig, "6person-multi-mono.gif")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="3d9f1ef2-cc53-4ff8-bfd5-bb6b1a0c2ac1" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3d9f1ef2-cc53-4ff8-bfd5-bb6b1a0c2ac1")) {                    Plotly.newPlot(                        "3d9f1ef2-cc53-4ff8-bfd5-bb6b1a0c2ac1",                        [{"hoverinfo":"name","line":{"color":"grey"},"mode":"lines","name":"Exterior","showlegend":false,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAChAAAAAAAAAKEAAAAAAAAAkQAAAAAAAACRAAAAAAAAAAAA="},"y":{"dtype":"f8","bdata":"AAAAAAAAAEAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAKEAAAAAAAAAoQAAAAAAAAABAAAAAAAAAAEA="},"type":"scatter"},{"hoverinfo":"none","marker":{"cmax":1.3937723457176077,"cmin":0,"color":{"dtype":"f8","bdata":"wvwV5bo00T+XKzUpk\u002fP0P3SR+bp8XPE\u002fRuTyDnt80z+ar7idjRTQP9NBnUVSR\u002fQ\u002f"},"colorbar":{"title":{"text":"Speed [m\u002fs]"}},"colorscale":[[0.0,"rgb(128,0,0)"],[0.2,"rgb(250,0,0)"],[0.4,"rgb(255,255,0)"],[0.6,"rgb(5,255,255)"],[0.8,"rgb(0,60,170)"],[1.0,"rgb(0,0,131)"]],"size":{"dtype":"f8","bdata":"mpmZmZmZ2T+amZmZmZnZP5qZmZmZmdk\u002fmpmZmZmZ2T+amZmZmZnZP5qZmZmZmdk\u002f"}},"mode":"markers","showlegend":false,"text":{"dtype":"f8","bdata":"wvwV5bo00T+XKzUpk\u002fP0P3SR+bp8XPE\u002fRuTyDnt80z+ar7idjRTQP9NBnUVSR\u002fQ\u002f"},"x":{"dtype":"f8","bdata":"fc1W616REUBGMrPSoPTtPxRAC\u002fbZTdY\u002fhHHbUoDaDED4ztAPh\u002foTQJz\u002fVq8ONf0\u002f"},"y":{"dtype":"f8","bdata":"sCxj1jUo8z9Mf5nhoPfTP7W3VQm3t\u002fs\u002fgoKa0oeo9j+YMAOQ7S3bP2M8BwDOyvA\u002f"},"type":"scatter"},{"hoverinfo":"text","marker":{"opacity":1,"size":1},"mode":"markers","showlegend":false,"text":["ID: 2, Pos(4.39,1.20)"],"x":[4.391963650868431],"y":[1.1973169683940732],"type":"scatter"},{"hoverinfo":"text","marker":{"opacity":1,"size":1},"mode":"markers","showlegend":false,"text":["ID: 4, Pos(0.94,0.31)"],"x":[0.9361118426546191],"y":[0.3119890406724053],"type":"scatter"},{"hoverinfo":"text","marker":{"opacity":1,"size":1},"mode":"markers","showlegend":false,"text":["ID: 6, Pos(0.35,1.73)"],"x":[0.34850167300919677],"y":[1.7323522915498704],"type":"scatter"},{"hoverinfo":"text","marker":{"opacity":1,"size":1},"mode":"markers","showlegend":false,"text":["ID: 8, Pos(3.61,1.42)"],"x":[3.606690070459253],"y":[1.416145155592091],"type":"scatter"},{"hoverinfo":"text","marker":{"opacity":1,"size":1},"mode":"markers","showlegend":false,"text":["ID: 10, Pos(4.99,0.42)"],"x":[4.99465584480253],"y":[0.4246782213565523],"type":"scatter"},{"hoverinfo":"text","marker":{"opacity":1,"size":1},"mode":"markers","showlegend":false,"text":["ID: 12, Pos(1.83,1.05)"],"x":[1.8254534577572263],"y":[1.0495128632644757],"type":"scatter"}],                        {"shapes":[{"fillcolor":"rgba(218, 0, 0, 0.5)","line":{"color":"rgba(218, 0, 0, 0.5)"},"type":"circle","x0":4.191963650868431,"x1":4.591963650868431,"xref":"x","y0":0.9973169683940732,"y1":1.3973169683940732,"yref":"y"},{"fillcolor":"rgba(0, 0, 205, 0.5)","line":{"color":"rgba(0, 0, 205, 0.5)"},"type":"circle","x0":0.7361118426546192,"x1":1.136111842654619,"xref":"x","y0":0.11198904067240528,"y1":0.5119890406724052,"yref":"y"},{"fillcolor":"rgba(0, 128, 255, 0.5)","line":{"color":"rgba(0, 128, 255, 0.5)"},"type":"circle","x0":0.14850167300919676,"x1":0.5485016730091967,"xref":"x","y0":1.5323522915498704,"y1":1.9323522915498703,"yref":"y"},{"fillcolor":"rgba(255, 19, 0, 0.5)","line":{"color":"rgba(255, 19, 0, 0.5)"},"type":"circle","x0":3.406690070459253,"x1":3.8066900704592532,"xref":"x","y0":1.216145155592091,"y1":1.616145155592091,"yref":"y"},{"fillcolor":"rgba(205, 0, 0, 0.5)","line":{"color":"rgba(205, 0, 0, 0.5)"},"type":"circle","x0":4.79465584480253,"x1":5.19465584480253,"xref":"x","y0":0.2246782213565523 ...

# %% [markdown]
# As expected the agents choose the shortest path and approach the corner in a funnel-shaped formation. Agents moving closer to the corner become slower than agents at the edge of the crowd who choose a longer path around the corner.

# %% [markdown]
# # Download
#
# This notebook can be directly downloaded {download}`here <./corner.ipynb>` to run it locally.

# %% [markdown]
# ## References & Further Exploration
#
# [1] RiMEA, 'Guideline for Microscopic Evacuation Analysis'(2016), URL: https://rimea.de/
#
# Another RiMEA test regarding the movement in bottlenecks can be found [here](double-bottleneck).
#
# This examples shows the basic behaviour of agents when moving around corners. A more advanced simulation and analysis can be found [here](journey).
#
# The demonstration employed a straightforward journey with a singular exit. For a more intricate journey featuring multiple intermediate stops and waiting zones, see the [upcoming section](journey).
