# %% [markdown]
# # Movement around Corners
#
# This notebook can be directly downloaded {download}`here <./corner.ipynb>` to run it locally.
#
# In the following we'll investigate the movement of pedestrians around corners. When pedestrians walk around corners they are expected to slow down and take a path that is close to the corner. According to RiMEA Test 6 [1] a scenario is configured where **20 agents** move towards a **corner** at which they should turn to the left.
#
# Let's begin by importing the required packages for our simulation:

# %%
import pathlib

import jupedsim as jps
import pedpy
from numpy.random import normal  # normal distribution of free movement speed
from shapely import Polygon

# %% [markdown]
# ## Setting up the Geometry
#
# According to the RiMEA Test we define a corridor with a width of 2 meters and a corner on halfway:

# %%
area = Polygon([(0, 0), (12, 0), (12, 12), (10, 12), (10, 2), (0, 2)])
walkable_area = pedpy.WalkableArea(area)
pedpy.plot_walkable_area(walkable_area=walkable_area).set_aspect("equal")

# %% [markdown]
# ## Definition of Start Positions and Exit
#
# Now we'll calculate the position of 20 agents in the lower left part of the geometry within an rectangle of 6 x 2 meters. For this purpose, we use a library function from JuPedSim that calclulates positions in a given polygon. We assume an agent size of 0.4 m (diameter) and set the distance parameters accordingly. The exit is defined in the upper right of the geometry.

# %%
spawning_area = Polygon([(0, 0), (6, 0), (6, 2), (0, 2)])
num_agents = 6
pos_in_spawning_area = jps.distributions.distribute_by_number(
    polygon=spawning_area,
    number_of_agents=num_agents,
    distance_to_agents=0.4,
    distance_to_polygon=0.2,
    seed=42,
)
exit_area = Polygon([(10, 11), (12, 11), (12, 12), (10, 12)])

# %% [markdown]
# Let's have a look at the basic simulation setup. The spawning area is shown in grey, the agents in blue and the exit area in red:

# %%
def plot_simulation_configuration(
    walkable_area, spawning_area, starting_positions, exit_area
):
    axes = pedpy.plot_walkable_area(walkable_area=walkable_area)
    axes.fill(*spawning_area.exterior.xy, color="lightgrey")
    axes.fill(*exit_area.exterior.xy, color="indianred")
    axes.scatter(*zip(*starting_positions))
    axes.set_xlabel("x/m")
    axes.set_ylabel("y/m")
    axes.set_aspect("equal")

# %%
plot_simulation_configuration(
    walkable_area, spawning_area, pos_in_spawning_area, exit_area
)

# %% [markdown]
# ## Setting up the Simulation and Routing Details
#
# As a next step we create a simulation object, set the configuration for the operational model (collision-free speed model) and define the routes for the agents. Default values for the model parameters are set implicitly. For this scenario, only one journey is created as all agents should follow the same route.

# %%
from jupedsim_examples.models.multi_model import MultiModel
from jupedsim import CollisionFreeSpeedModel
trajectory_file = "corner.sqlite"  # output file

simulation = jps.Simulation(
    model=MultiModel(CollisionFreeSpeedModel()),
    geometry=area,
    trajectory_writer=jps.SqliteTrajectoryWriter(
        output_file=pathlib.Path(trajectory_file),
    ),
)

# %%
exit_id = simulation.add_exit_stage(exit_area.exterior.coords[:-1])
journey = jps.JourneyDescription([exit_id])
journey_id = simulation.add_journey(journey)

# %% [markdown]
# ## Agent Parameters and Executing the Simulation
#
# As a next step we define the agent parameters and add them to the simulation. They share the same journey and model parameters except for the starting position and free movement speed which is normally distributed. After adding the agents, the simulation is started and iterates until all agents have reached the exit.

# %%
from jupedsim import CustomModelAgentParameters

v_distribution = normal(1.34, 0.05, num_agents)
i = 0
for pos, v0 in zip(pos_in_spawning_area, v_distribution):
    param = CustomModelAgentParameters()
    param.journey_id = journey_id
    param.stage_id = exit_id
    param.position = pos
    param.desired_speed = v0
    param.orientation = (0,0)
    param.model_id = 1 if i % 2 == 0 else 2
    param.radius = 0.25
    param.time_gap = 1.0
    param.velocity = (0.0, 0.0)
    simulation.add_agent(
        param
    )
    i += 1

while simulation.agent_count() > 0 and simulation.iteration_count() < 5000:
    simulation.iterate()
simulation._writer.close()
# Out:
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555352142, 0.1621299450254612)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555352803, 0.16212994502488892)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555353514, 0.16212994502426836)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755535429, 0.16212994502359543)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555355128, 0.16212994502286573)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555356039, 0.16212994502207453)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555357024, 0.16212994502121658)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555358095, 0.16212994502028621)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555359256, 0.16212994501927736)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555360513, 0.16212994501818345)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555361876, 0.16212994501699723)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555363355, 0.16212994501571099)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755536496, 0.16212994501431618)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555366701, 0.16212994501280373)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555368586, 0.16212994501116368)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555370634, 0.1621299450093853)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755537285, 0.1621299450074569)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555375254, 0.16212994500536582)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555377861, 0.16212994500309838)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555380692, 0.16212994500063965)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555383756, 0.16212994499797356)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555387083, 0.16212994499508254)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555390686, 0.16212994499194763)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555394597, 0.16212994498854838)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555398835, 0.16212994498486236)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555403434, 0.1621299449808654)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755540842, 0.16212994497653135)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555413824, 0.1621299449718317)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555419685, 0.16212994496673558)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755542604, 0.16212994496120964)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555432933, 0.16212994495521763)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555440404, 0.1621299449487201)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555448507, 0.1621299449416746)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555457295, 0.16212994493403482)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555466823, 0.16212994492575064)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555477155, 0.16212994491676774)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555488357, 0.16212994490702715)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555500505, 0.16212994489646493)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755551368, 0.16212994488501195)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755552796, 0.1621299448725929)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755554345, 0.16212994485912643)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555560244, 0.16212994484452412)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555578456, 0.16212994482869028)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555598203, 0.16212994481152093)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555619614, 0.16212994479290346)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555642834, 0.16212994477271583)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755566801, 0.1621299447508256)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755569531, 0.16212994472708908)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755572491, 0.16212994470135073)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555757011, 0.1621299446734416)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555791817, 0.16212994464317865)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755582956, 0.16212994461036345)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555870485, 0.1621299445747807)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677555914858, 0.16212994453619697)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755596298, 0.16212994449435936)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677556015156, 0.1621299444489933)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677556071733, 0.16212994439980133)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755613308, 0.16212994434646089)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677556199602, 0.1621299442886221)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677556271733, 0.1621299442259056)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755634995, 0.16212994415790005)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755643476, 0.16212994408415954)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677556526724, 0.16212994400420044)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755662644, 0.16212994391749838)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677556734571, 0.1621299438234849)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677556851818, 0.1621299437215433)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.409667755697895, 0.16212994361100527)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677557116803, 0.16212994349114582)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677557266282, 0.162129943361179)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677557428365, 0.1621299432202527)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677557604118, 0.16212994306744277)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677557794688, 0.16212994290174718)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677558001327, 0.16212994272207953)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677558225394, 0.16212994252726176)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677558468353, 0.1621299423160165)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.40966775587318, 0.16212994208695872)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096677559017459, 0.16212994183858664)
# []
# 1.7976931348623157e+308
# 1.4189606407753697
# Point(1.4096
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpe6mzvvts/index.html
#   Getting tab from queue (has 1)
#   Got 6467
#   Reloading tab 6467 before return.
#   Putting tab 6467 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 4 captured. (elapsed time: 0.0 min; 7 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpo4pzbzpw.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpgjo_tlda.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpgjo_tlda
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpo4pzbzpw/index.html
#   Getting tab from queue (has 1)
#   Got B48E
#   Reloading tab B48E before return.
#   Putting tab B48E back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 5 captured. (elapsed time: 0.0 min; 9 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpsuq86437.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp1cmnuxtg.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp1cmnuxtg
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpsuq86437/index.html
#   Getting tab from queue (has 1)
#   Got F0D0
#   Reloading tab F0D0 before return.
#   Putting tab F0D0 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 6 captured. (elapsed time: 0.0 min; 10 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpz5qcalu2.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp2izxzua_.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp2izxzua_
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpz5qcalu2/index.html
#   Getting tab from queue (has 1)
#   Got 1878
#   Reloading tab 1878 before return.
#   Putting tab 1878 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 7 captured. (elapsed time: 0.0 min; 12 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp55i7iy93.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpokvhl2td.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpokvhl2td
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp55i7iy93/index.html
#   Getting tab from queue (has 1)
#   Got 0EE8
#   Reloading tab 0EE8 before return.
#   Putting tab 0EE8 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 8 captured. (elapsed time: 0.0 min; 13 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpgba7jjqb.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp5geja9ms.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp5geja9ms
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpgba7jjqb/index.html
#   Getting tab from queue (has 1)
#   Got 1747
#   Reloading tab 1747 before return.
#   Putting tab 1747 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 9 captured. (elapsed time: 0.0 min; 15 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3raj00x4.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpjw1n8g66.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpjw1n8g66
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3raj00x4/index.html
#   Getting tab from queue (has 1)
#   Got AA3B
#   Reloading tab AA3B before return.
#   Putting tab AA3B back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 10 captured. (elapsed time: 0.0 min; 17 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp8nohfuq2.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp73e1j_fy.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp73e1j_fy
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp8nohfuq2/index.html
#   Getting tab from queue (has 1)
#   Got D003
#   Reloading tab D003 before return.
#   Putting tab D003 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 11 captured. (elapsed time: 0.0 min; 19 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpf56d2ryu.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmptyiza6qm.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmptyiza6qm
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpf56d2ryu/index.html
#   Getting tab from queue (has 1)
#   Got 78EA
#   Reloading tab 78EA before return.
#   Putting tab 78EA back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 12 captured. (elapsed time: 0.0 min; 20 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpqfl0ni7j.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpbtj6ixat.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpbtj6ixat
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpqfl0ni7j/index.html
#   Getting tab from queue (has 1)
#   Got F70F
#   Reloading tab F70F before return.
#   Putting tab F70F back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 13 captured. (elapsed time: 0.0 min; 22 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpd408u61p.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpcyf1rrgj.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpcyf1rrgj
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpd408u61p/index.html
#   Getting tab from queue (has 1)
#   Got EA5D
#   Reloading tab EA5D before return.
#   Putting tab EA5D back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 14 captured. (elapsed time: 0.0 min; 24 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3wmaq74m.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpbaei34yp.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpbaei34yp
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3wmaq74m/index.html
#   Getting tab from queue (has 1)
#   Got 9175
#   Reloading tab 9175 before return.
#   Putting tab 9175 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 15 captured. (elapsed time: 0.0 min; 25 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpq1620fvt.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpvo8nga4y.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpvo8nga4y
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpq1620fvt/index.html
#   Getting tab from queue (has 1)
#   Got C6B1
#   Reloading tab C6B1 before return.
#   Putting tab C6B1 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 16 captured. (elapsed time: 0.0 min; 27 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpwqrpfnsc.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpu1vca8yz.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpu1vca8yz
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpwqrpfnsc/index.html
#   Getting tab from queue (has 1)
#   Got C78E
#   Reloading tab C78E before return.
#   Putting tab C78E back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 17 captured. (elapsed time: 0.0 min; 28 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpxr026i97.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpjp6fa9zu.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpjp6fa9zu
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpxr026i97/index.html
#   Getting tab from queue (has 1)
#   Got 8CD7
#   Reloading tab 8CD7 before return.
#   Putting tab 8CD7 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 18 captured. (elapsed time: 0.0 min; 30 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpq5d8ualk.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp0cg5rogn.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp0cg5rogn
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpq5d8ualk/index.html
#   Getting tab from queue (has 1)
#   Got 535F
#   Reloading tab 535F before return.
#   Putting tab 535F back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 19 captured. (elapsed time: 0.0 min; 32 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpz_n3o_we.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3nbb0man.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3nbb0man
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpz_n3o_we/index.html
#   Getting tab from queue (has 1)
#   Got 2926
#   Reloading tab 2926 before return.
#   Putting tab 2926 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 20 captured. (elapsed time: 0.0 min; 33 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpw1pwe_hy.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpfimnmenh.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpfimnmenh
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpw1pwe_hy/index.html
#   Getting tab from queue (has 1)
#   Got 1A0E
#   Reloading tab 1A0E before return.
#   Putting tab 1A0E back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 21 captured. (elapsed time: 0.0 min; 35 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp96lokqpm.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpg55dvjf8.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpg55dvjf8
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp96lokqpm/index.html
#   Getting tab from queue (has 1)
#   Got 7543
#   Reloading tab 7543 before return.
#   Putting tab 7543 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 22 captured. (elapsed time: 0.0 min; 37 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpzu3sgxc0.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp_7s6j3fm.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp_7s6j3fm
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpzu3sgxc0/index.html
#   Getting tab from queue (has 1)
#   Got AB05
#   Reloading tab AB05 before return.
#   Putting tab AB05 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 23 captured. (elapsed time: 0.0 min; 38 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp0oxb4xf3.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp25r8jxto.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp25r8jxto
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp0oxb4xf3/index.html
#   Getting tab from queue (has 1)
#   Got B1B0
#   Reloading tab B1B0 before return.
#   Putting tab B1B0 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 24 captured. (elapsed time: 0.0 min; 40 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp2h37t0mu.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpfst7856u.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpfst7856u
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp2h37t0mu/index.html
#   Getting tab from queue (has 1)
#   Got C8FE
#   Reloading tab C8FE before return.
#   Putting tab C8FE back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 25 captured. (elapsed time: 0.0 min; 42 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmplmlio9t5.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpe8j72_k8.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpe8j72_k8
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmplmlio9t5/index.html
#   Getting tab from queue (has 1)
#   Got BA5A
#   Reloading tab BA5A before return.
#   Putting tab BA5A back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 26 captured. (elapsed time: 0.0 min; 43 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpytuyh5h8.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp6524a993.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp6524a993
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpytuyh5h8/index.html
#   Getting tab from queue (has 1)
#   Got FA03
#   Reloading tab FA03 before return.
#   Putting tab FA03 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 27 captured. (elapsed time: 0.0 min; 45 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpqtcr3lsr.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpo3fru158.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpo3fru158
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpqtcr3lsr/index.html
#   Getting tab from queue (has 1)
#   Got CA87
#   Reloading tab CA87 before return.
#   Putting tab CA87 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 28 captured. (elapsed time: 0.0 min; 47 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3yrebmvl.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpwssbx6j_.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpwssbx6j_
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3yrebmvl/index.html
#   Getting tab from queue (has 1)
#   Got 697F
#   Reloading tab 697F before return.
#   Putting tab 697F back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 29 captured. (elapsed time: 0.0 min; 48 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmprvb7mfr_.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpk2glwnvc.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpk2glwnvc
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmprvb7mfr_/index.html
#   Getting tab from queue (has 1)
#   Got 6D11
#   Reloading tab 6D11 before return.
#   Putting tab 6D11 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 30 captured. (elapsed time: 0.0 min; 50 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpfnnjd7v8.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp9qrv9hox.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp9qrv9hox
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpfnnjd7v8/index.html
#   Getting tab from queue (has 1)
#   Got A5B2
#   Reloading tab A5B2 before return.
#   Putting tab A5B2 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 31 captured. (elapsed time: 0.0 min; 51 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp8ruw_8ha.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpzl5r1k0_.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpzl5r1k0_
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp8ruw_8ha/index.html
#   Getting tab from queue (has 1)
#   Got DF49
#   Reloading tab DF49 before return.
#   Putting tab DF49 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 32 captured. (elapsed time: 0.0 min; 53 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmplqjw0vw6.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpu_6ko01i.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpu_6ko01i
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmplqjw0vw6/index.html
#   Getting tab from queue (has 1)
#   Got 5814
#   Reloading tab 5814 before return.
#   Putting tab 5814 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 33 captured. (elapsed time: 0.0 min; 55 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp77hl24zb.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpedki2vbn.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpedki2vbn
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp77hl24zb/index.html
#   Getting tab from queue (has 1)
#   Got 440B
#   Reloading tab 440B before return.
#   Putting tab 440B back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 34 captured. (elapsed time: 0.0 min; 56 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpx916ntj1.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpxnv6vyrv.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpxnv6vyrv
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpx916ntj1/index.html
#   Getting tab from queue (has 1)
#   Got FB88
#   Reloading tab FB88 before return.
#   Putting tab FB88 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 35 captured. (elapsed time: 0.0 min; 58 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpclvfy84v.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpgm2n70ty.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpgm2n70ty
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpclvfy84v/index.html
#   Getting tab from queue (has 1)
#   Got 00F3
#   Reloading tab 00F3 before return.
#   Putting tab 00F3 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 36 captured. (elapsed time: 1.0 min; 0 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpse9nzwzb.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp7zcxq91r.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp7zcxq91r
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpse9nzwzb/index.html
#   Getting tab from queue (has 1)
#   Got EF49
#   Reloading tab EF49 before return.
#   Putting tab EF49 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 37 captured. (elapsed time: 1.0 min; 1 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpiti6pzwh.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpf6qwixyt.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpf6qwixyt
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpiti6pzwh/index.html
#   Getting tab from queue (has 1)
#   Got 9E35
#   Reloading tab 9E35 before return.
#   Putting tab 9E35 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 38 captured. (elapsed time: 1.0 min; 3 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpqm3gqvy_.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpo9uvqca7.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpo9uvqca7
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpqm3gqvy_/index.html
#   Getting tab from queue (has 1)
#   Got 4091
#   Reloading tab 4091 before return.
#   Putting tab 4091 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 39 captured. (elapsed time: 1.0 min; 5 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpxnlqtkpl.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp5viqycfx.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp5viqycfx
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpxnlqtkpl/index.html
#   Getting tab from queue (has 1)
#   Got 6489
#   Reloading tab 6489 before return.
#   Putting tab 6489 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 40 captured. (elapsed time: 1.0 min; 6 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpdxplhcd2.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmper6jvub0.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmper6jvub0
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpdxplhcd2/index.html
#   Getting tab from queue (has 1)
#   Got 2665
#   Reloading tab 2665 before return.
#   Putting tab 2665 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 41 captured. (elapsed time: 1.0 min; 8 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpucyno068.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp0785p457.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp0785p457
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpucyno068/index.html
#   Getting tab from queue (has 1)
#   Got E558
#   Reloading tab E558 before return.
#   Putting tab E558 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 42 captured. (elapsed time: 1.0 min; 9 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp8pk0k745.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpq7esa41x.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpq7esa41x
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp8pk0k745/index.html
#   Getting tab from queue (has 1)
#   Got AD02
#   Reloading tab AD02 before return.
#   Putting tab AD02 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 43 captured. (elapsed time: 1.0 min; 11 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpufk42ml9.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp7wy176pz.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp7wy176pz
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpufk42ml9/index.html
#   Getting tab from queue (has 1)
#   Got 9602
#   Reloading tab 9602 before return.
#   Putting tab 9602 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 44 captured. (elapsed time: 1.0 min; 13 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp7b80uk05.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp1s9de19p.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp1s9de19p
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp7b80uk05/index.html
#   Getting tab from queue (has 1)
#   Got 3B05
#   Reloading tab 3B05 before return.
#   Putting tab 3B05 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 45 captured. (elapsed time: 1.0 min; 14 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpix859g45.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpuaxftl73.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpuaxftl73
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpix859g45/index.html
#   Getting tab from queue (has 1)
#   Got C9EF
#   Reloading tab C9EF before return.
#   Putting tab C9EF back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
# ...
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 58 captured. (elapsed time: 1.0 min; 36 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp518em54z.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpkpujb_q9.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpkpujb_q9
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp518em54z/index.html
#   Getting tab from queue (has 1)
#   Got 8A1D
#   Reloading tab 8A1D before return.
#   Putting tab 8A1D back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 59 captured. (elapsed time: 1.0 min; 38 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp_uz_8bxg.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpn6els5ry.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpn6els5ry
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp_uz_8bxg/index.html
#   Getting tab from queue (has 1)
#   Got 437C
#   Reloading tab 437C before return.
#   Putting tab 437C back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 60 captured. (elapsed time: 1.0 min; 39 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp48ygz4u4.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmprcysz1no.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmprcysz1no
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp48ygz4u4/index.html
#   Getting tab from queue (has 1)
#   Got E078
#   Reloading tab E078 before return.
#   Putting tab E078 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 61 captured. (elapsed time: 1.0 min; 41 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpe14k6elx.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpshxxc1z8.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpshxxc1z8
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpe14k6elx/index.html
#   Getting tab from queue (has 1)
#   Got 3C3B
#   Reloading tab 3C3B before return.
#   Putting tab 3C3B back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 62 captured. (elapsed time: 1.0 min; 43 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpd_8dm1iq.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpf6hr8tpe.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpf6hr8tpe
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpd_8dm1iq/index.html
#   Getting tab from queue (has 1)
#   Got 20C6
#   Reloading tab 20C6 before return.
#   Putting tab 20C6 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 63 captured. (elapsed time: 1.0 min; 44 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpjglgwap1.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpbk_5320_.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpbk_5320_
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpjglgwap1/index.html
#   Getting tab from queue (has 1)
#   Got 0ABA
#   Reloading tab 0ABA before return.
#   Putting tab 0ABA back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 64 captured. (elapsed time: 1.0 min; 46 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpd50vbuxs.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpod78640g.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpod78640g
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpd50vbuxs/index.html
#   Getting tab from queue (has 1)
#   Got A1D8
#   Reloading tab A1D8 before return.
#   Putting tab A1D8 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 65 captured. (elapsed time: 1.0 min; 48 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpbe4_odb6.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp6pmc4gtg.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp6pmc4gtg
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpbe4_odb6/index.html
#   Getting tab from queue (has 1)
#   Got 6B30
#   Reloading tab 6B30 before return.
#   Putting tab 6B30 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 66 captured. (elapsed time: 1.0 min; 49 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpr6a5pm0u.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpdbm3de4b.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpdbm3de4b
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpr6a5pm0u/index.html
#   Getting tab from queue (has 1)
#   Got 74A0
#   Reloading tab 74A0 before return.
#   Putting tab 74A0 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 67 captured. (elapsed time: 1.0 min; 51 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpy35fcr7e.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpiy7cts9k.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpiy7cts9k
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpy35fcr7e/index.html
#   Getting tab from queue (has 1)
#   Got EC1E
#   Reloading tab EC1E before return.
#   Putting tab EC1E back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 68 captured. (elapsed time: 1.0 min; 53 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpx89crqw7.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpjwkytmtq.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpjwkytmtq
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpx89crqw7/index.html
#   Getting tab from queue (has 1)
#   Got CCF0
#   Reloading tab CCF0 before return.
#   Putting tab CCF0 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 69 captured. (elapsed time: 1.0 min; 55 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp5mn8lq5z.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp9qhfqyzj.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp9qhfqyzj
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp5mn8lq5z/index.html
#   Getting tab from queue (has 1)
#   Got C731
#   Reloading tab C731 before return.
#   Putting tab C731 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 70 captured. (elapsed time: 1.0 min; 56 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp6ir_gomb.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp_l34k7ii.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp_l34k7ii
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp6ir_gomb/index.html
#   Getting tab from queue (has 1)
#   Got 461E
#   Reloading tab 461E before return.
#   Putting tab 461E back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 71 captured. (elapsed time: 1.0 min; 58 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpgwpjz2at.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3j7eowk9.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmp3j7eowk9
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpgwpjz2at/index.html
#   Getting tab from queue (has 1)
#   Got 2692
#   Reloading tab 2692 before return.
#   Putting tab 2692 back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 72 captured. (elapsed time: 1.0 min; 59 sec)
#   Chromium init'ed with kwargs {}
#   Found chromium path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpafbq989p.
#   Opening browser.
#   Temp directory created: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpijf6ehyn.
#   Temporary directory at: /var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpijf6ehyn
#   Conforming 1 to file:///var/folders/gj/s8577c_175g9y72sxl8skkvr0000gn/T/tmpafbq989p/index.html
#   Getting tab from queue (has 1)
#   Got 7E2C
#   Reloading tab 7E2C before return.
#   Putting tab 7E2C back (queue size: 0).
#   Waiting for all cleanups to finish.
#   Exiting Kaleido.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Closing browser.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   TemporaryDirectory.cleanup() worked.
#   shutil.rmtree worked.
#   Cancelling tasks.
#   Exiting Kaleido/Choreo.
#   Image 73 captured. (elapsed time: 2.0 min; 1 sec)
#   gif created: 6person-multi-mono.gif (time to generate gif: 0.0 min; 0 sec)

# %% [markdown]
# As expected the agents choose the shortest path and approach the corner in a funnel-shaped formation. Agents moving closer to the corner become slower than agents at the edge of the crowd who choose a longer path around the corner.

# %% [markdown]
# # Download
#
# This notebook can be directly downloaded {download}`here <./corner.ipynb>` to run it locally.

# %% [markdown]
# ## References & Further Exploration
#
# [1] RiMEA, 'Guideline for Microscopic Evacuation Analysis'(2016), URL: https://rimea.de/
#
# Another RiMEA test regarding the movement in bottlenecks can be found [here](double-bottleneck).
#
# This examples shows the basic behaviour of agents when moving around corners. A more advanced simulation and analysis can be found [here](journey).
#
# The demonstration employed a straightforward journey with a singular exit. For a more intricate journey featuring multiple intermediate stops and waiting zones, see the [upcoming section](journey).
